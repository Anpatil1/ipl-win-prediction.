# %% [markdown]
# # IPL WINNER PROBABILITY PREDICTION PROJECT
#
# Dataset has been taken from Kaggle : https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset
#
# #### This notebook has been created to get the following data:
# - Batting Team
# - Bowling Team
# - City
# - Runs Left
# - Balls Left
# - Wickets Out
# - Current Run Rate
# - Required Run Rate
# - Result (Winner)

# %% [markdown]
# ### (1) Load the datasets

# %%
import numpy as np
import pandas as pd

# %%
match_df = pd.read_csv('../data/IPL_Matches_2008_2022.csv')
delivery_df = pd.read_csv('../data/IPL_Ball_by_Ball_2008_2022.csv')

# %%
match_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
delivery_df.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %% [markdown]
# ### (2) Shape of the dataset

# %%
match_df.shape
# Out:
# (950, 20)

# %%
delivery_df.shape
# Out:
# (225954, 17)

# %% [markdown]
# ### (3) Generating columns with text data required for prediction

# %% [markdown]
# **Merge the two datasets**

# %%
delivery_df = match_df.merge(delivery_df, on='ID')

# %%
delivery_df.head()
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 2  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 3  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 4  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 2  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 4  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... extra_type batsman_run extras_run  total_run non_boundary  \
# ...

# %% [markdown]
# **Filter the teams and keep the relevant ones**

# %%
delivery_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
teams = [
    'Rajasthan Royals',
    'Royal Challengers Bangalore',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Chennai Super Kings',
    'Gujarat Titans',
    'Lucknow Super Giants',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Mumbai Indians'
]

# %% [markdown]
# Batting team already exists

# %%
delivery_df['Team1'] = delivery_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['Team2'] = delivery_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['WinningTeam'] = delivery_df['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')
delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

delivery_df['Team1'] = delivery_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['Team2'] = delivery_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['WinningTeam'] = delivery_df['WinningTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

delivery_df['Team1'] = delivery_df['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
delivery_df['Team2'] = delivery_df['Team2'].str.replace('Gujarat Lions','Gujarat Titans')
delivery_df['WinningTeam'] = delivery_df['WinningTeam'].str.replace('Gujarat Lions','Gujarat Titans')
delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Gujarat Lions','Gujarat Titans')

delivery_df['Team1'] = delivery_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
delivery_df['Team2'] = delivery_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
delivery_df['WinningTeam'] = delivery_df['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')
delivery_df['BattingTeam'] = delivery_df['BattingTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
delivery_df = delivery_df[delivery_df['Team1'].isin(teams)]
delivery_df = delivery_df[delivery_df['Team2'].isin(teams)]
delivery_df = delivery_df[delivery_df['WinningTeam'].isin(teams)]
delivery_df = delivery_df[delivery_df['BattingTeam'].isin(teams)]

# %%
delivery_df.shape
# Out:
# (204772, 36)

# %% [markdown]
# **Generating the 'Bowling Team' column**

# %%
def bowl(row):
    if row['Team1'] == row['BattingTeam']:
        return row['Team2']
    else:
        return row['Team1']

# %%
delivery_df['BowlingTeam'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df.head()
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 2  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 3  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 4  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 2  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 4  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... batsman_run extras_run total_run  non_boundary  \
# ...

# %% [markdown]
# **Filter the cities and keep the relevant ones**

# %%
delivery_df['City'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Nagpur', 'Johannesburg', 'Centurion', 'Durban',
#        'Bloemfontein', 'Port Elizabeth', 'Kimberley', 'East London',
#        'Cape Town'], dtype=object)

# %%
cities=['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
       'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai','Hyderabad',
       'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
       'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
       'Dharamsala', 'Nagpur', 'Johannesburg', 'Centurion', 'Durban',
       'Bloemfontein', 'Port Elizabeth', 'Kimberley', 'East London',
       'Cape Town']

# %%
delivery_df['City'] = delivery_df['City'].str.replace('Bangalore','Bengaluru')
delivery_df['City'] = delivery_df['City'].str.replace('Dharamsala','Dharamshala')

# %%
delivery_df = delivery_df[delivery_df['City'].isin(cities)]

# %% [markdown]
# ### (4) Group by Innings

# %%
total_scores_df = delivery_df.groupby(['ID','innings']).sum()['total_run'].reset_index()
# Out:
# /tmp/ipykernel_9196/1386064346.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_scores_df = delivery_df.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_scores_df
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 1      335982        2         82
# 2      335983        1        240
# 3      335983        2        207
# 4      335984        1        129
# ...       ...      ...        ...
# 1613  1312198        2        193
# 1614  1312199        1        157
# 1615  1312199        2        161
# 1616  1312200        1        130
# 1617  1312200        2        133
#
# [1618 rows x 3 columns]

# %% [markdown]
# **Group by first innings**

# %%
total_scores_df = total_scores_df[total_scores_df['innings'] == 1]

# %%
total_scores_df.head()
# Out:
#        ID  innings  total_run
# 0  335982        1        222
# 2  335983        1        240
# 4  335984        1        129
# 6  335985        1        165
# 8  335986        1        110

# %% [markdown]
# **Generating 'target' column**

# %%
total_scores_df = total_scores_df.rename(columns={'total_run': 'target'})

# %%
total_scores_df.head()
# Out:
#        ID  innings  target
# 0  335982        1     222
# 2  335983        1     240
# 4  335984        1     129
# 6  335985        1     165
# 8  335986        1     110

# %%
delivery_df =delivery_df.merge(total_scores_df[['ID','target']], on='ID')

# %% [markdown]
# **Group by second innings**

# %%
delivery_df = delivery_df[delivery_df['innings'] == 2]

# %%
delivery_df
# Out:
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 190211   335982  Bengaluru  2008-04-18  2007/08           1
# 190212   335982  Bengaluru  2008-04-18  2007/08           1
# 190213   335982  Bengaluru  2008-04-18  2007/08           1
# 190214   335982  Bengaluru  2008-04-18  2007/08           1
# 190215   335982  Bengaluru  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# ...

# %% [markdown]
# ### (5) Generate rest of the required columns for prediction

# %% [markdown]
# **'Current Score'**

# %%
delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run']
# Out:
# /tmp/ipykernel_9196/1194907366.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score'] = delivery_df.groupby('ID').cumsum()['total_run']

# %% [markdown]
# **'Runs Left'**

# %%
delivery_df['runs_left'] = delivery_df['target'] - delivery_df['current_score']+1

# %% [markdown]
# **'Balls Left'**

# %%
delivery_df['balls_left'] = 120 - (delivery_df['overs']*6 + delivery_df['ballnumber'])

# %% [markdown]
# **'Wickets Left'**

# %%
wickets = delivery_df.groupby('ID').cumsum()['isWicketDelivery'].values
delivery_df['wickets'] = 10 - wickets
# Out:
# /tmp/ipykernel_9196/1411168926.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = delivery_df.groupby('ID').cumsum()['isWicketDelivery'].values

# %% [markdown]
# **'Current Run Rate'**

# %%
# current_run_rate = runs/overs
delivery_df['current_run_rate'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %% [markdown]
# **'Required Run Rate'**

# %%
# required_run_rate = runs_left/overs_left
delivery_df['required_run_rate'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %% [markdown]
# **'Result (Winner)'**

# %%
def result(row):
    if row['BattingTeam'] == row['WinningTeam']:
        return 1 
    else:
        return 0

# %%
delivery_df['Result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 190211   335982  Bengaluru  2008-04-18  2007/08           1
# 190212   335982  Bengaluru  2008-04-18  2007/08           1
# 190213   335982  Bengaluru  2008-04-18  2007/08           1
# 190214   335982  Bengaluru  2008-04-18  2007/08           1
# 190215   335982  Bengaluru  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# ...

# %% [markdown]
# ### (6) Creating the required dataframe

# %%
ultimate_df = delivery_df[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets','target','current_run_rate','required_run_rate','Result']]

# %%
ultimate_df
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 190211  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 190212  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 190213  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 190214  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
# 190215  Royal Challengers Bangalore  Kolkata Knight Riders  Bengaluru
#
#         runs_left  balls_left  wickets  target  current_run_rate  \
# ...

# %% [markdown]
# **Sampling the data**

# %%
ultimate_df = ultimate_df.sample(ultimate_df.shape[0])

# %%
ultimate_df.sample()
# Out:
#                BattingTeam   BowlingTeam    City  runs_left  balls_left  \
# 15462  Chennai Super Kings  Punjab Kings  Mumbai         83          30
#
#        wickets  target  current_run_rate  required_run_rate  Result
# 15462        3     180          6.533333               16.6       0

# %% [markdown]
# ### (7) Checking for anomalies

# %%
ultimate_df.isnull().sum()
# Out:
# BattingTeam           0
# BowlingTeam           0
# City                  0
# runs_left             0
# balls_left            0
# wickets               0
# target                0
# current_run_rate      0
# required_run_rate    11
# Result                0
# dtype: int64

# %%
ultimate_df.describe()
# Out:
#           runs_left    balls_left       wickets        target  \
# count  91818.000000  91818.000000  91818.000000  91818.000000
# mean      92.633874     62.848744      7.547921    164.994086
# std       49.791516     33.397554      2.145349     28.823673
# min      -15.000000     -2.000000      0.000000     67.000000
# 25%       53.000000     35.000000      6.000000    147.000000
# 50%       92.000000     64.000000      8.000000    165.000000
# 75%      130.000000     92.000000      9.000000    185.000000
# max      249.000000    119.000000     10.000000    248.000000
#
#        current_run_rate  required_run_rate        Result
# count      91818.000000       9.180700e+04  91818.000000
# mean           7.478732                NaN      0.536398
# std            2.274577                NaN      0.498676
# min            0.000000               -inf      0.000000
# 25%            6.300000       7.200000e+00      0.000000
# 50%            7.521757       8.880000e+00      1.000000
# ...

# %%
ultimate_df = ultimate_df[ultimate_df['balls_left'] != 0]

# %%
ultimate_df.describe()
# Out:
#           runs_left    balls_left       wickets        target  \
# count  91512.000000  91512.000000  91512.000000  91512.000000
# mean      92.876464     63.058899      7.563587    164.951296
# std       49.686611     33.254684      2.129743     28.828092
# min      -15.000000     -2.000000      0.000000     67.000000
# 25%       54.000000     35.000000      6.000000    147.000000
# 50%       92.000000     64.000000      8.000000    165.000000
# 75%      130.000000     92.000000      9.000000    185.000000
# max      249.000000    119.000000     10.000000    248.000000
#
#        current_run_rate  required_run_rate        Result
# count      91512.000000       91512.000000  91512.000000
# mean           7.477205          10.411531      0.537766
# std            2.277221          13.800783      0.498574
# min            0.000000        -516.000000      0.000000
# 25%            6.295082           7.200000      0.000000
# 50%            7.518987           8.869565      1.000000
# ...

# %%
ultimate_df.isnull().sum()
# Out:
# BattingTeam          0
# BowlingTeam          0
# City                 0
# runs_left            0
# balls_left           0
# wickets              0
# target               0
# current_run_rate     0
# required_run_rate    0
# Result               0
# dtype: int64

# %%
ultimate_df.shape
# Out:
# (91512, 10)

# %% [markdown]
# ### (8) Split the dataset into train and test datasets

# %%
X = ultimate_df.iloc[:,:-1]
Y = ultimate_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# ### (9) Encoding Text Data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['BattingTeam','BowlingTeam','City'])
]
,remainder='passthrough')

# %% [markdown]
# ### (10) Building the pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
Y_pred = pipe.predict(X_test)

# %% [markdown]
# ### (11) Model Evaluation

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.8150030049718625

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(Y_test,Y_pred))
# Out:
# 0.18499699502813746

# %%
pipe.predict_proba(X_test)[0]
# Out:
# array([0.95304837, 0.04695163])

# %% [markdown]
# ### (12) Send to pickle file

# %%
import pickle
pickle.dump(pipe,open('iplpipe.pkl','wb'))
